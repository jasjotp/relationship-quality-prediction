# %% [markdown]
# |        Name       | Preparation rating |
# |-------------------|--------------------|
# | Jade Chen         | 4                  |
# | Jasjot Parmar     | 4                  |
# | Johnson Leung     | 4                  |
# | Eugene Tse        | 4                  |

# %% [markdown]
# |        Name       | Participation & communication rating |
# |-------------------|--------------------|
# | Jade Chen         | 4                  |
# | Jasjot Parmar     | 4                  |
# | Johnson Leung     | 4                  |
# | Eugene Tse        | 4                  |

# %% [markdown]
# |        Name       | Helps group excel rating |
# |-------------------|--------------------|
# | Jade Chen         | 4                  |
# | Jasjot Parmar     | 4                  |
# | Johnson Leung     | 4                  |
# | Eugene Tse        | 4                  |

# %% [markdown]
# |        Name       | Team player (cooperation) rating |
# |-------------------|--------------------|
# | Jade Chen         | 4                  |
# | Jasjot Parmar     | 4                  |
# | Johnson Leung     | 4                  |
# | Eugene Tse        | 4                  |

# %% [markdown]
# **Roles and contributions**
#
# - **Jade Chen (me)**:
#     - data validations, preprocessing script, Makefile, project coordination, documentation
#
# - **Johnson Leung**:
#     - data validations, EDA, documentation, quarto document
#
# - **Jasjot Parmar**:
#     - data validations, download, quarto, references, project coordination, documentation
#
# - **Eugene Tse**:
#     - data validation, model scoring, project coordination, quarto, documentation
#
# **What went well**
#
# - clear division of tasks
# - effective Git workflow with minimal merge conflicts
#
# **What went poorly**
#
# - lots of edits that need to be made from peer reviews and TA feedback
# - honestly not much! everyone was pretty involved
